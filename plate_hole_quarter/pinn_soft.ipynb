# %%
"""Backend supported: pytorch, paddle, jax

Implementation of the linear elasticity 2D example in paper https://doi.org/10.1016/j.cma.2021.113741.
References:
    https://github.com/sciann/sciann-applications/blob/master/SciANN-Elasticity/Elasticity-Forward.ipynb.
"""

import deepxde as dde
import numpy as np
import time
import os
import argparse
import jax
import jax.numpy as jnp
from jaxopt import GaussNewton
from scipy.interpolate import RegularGridInterpolator
from functools import wraps
# Out:
# Using backend: jax
# Other supported backends: tensorflow.compat.v1, tensorflow, pytorch, paddle.
# paddle supports more examples now and is recommended.
# Enable just-in-time compilation with XLA.

# %%
n_iter = 1000
log_every = 100
available_time = 0
log_output_fields = {0: 'Ux', 1: 'Uy', 2: 'Sxx', 3: 'Syy', 4: 'Sxy'}
net_type = 'spinn'
bc_type = 'hard'
mlp = 'mlp'
n_DIC = 200
noise_magnitude = 0
lr = 0.001
u_0 = 1e-6
loss_weights = [1,1,1,1,1,1,1e2,1e2,1e2]

save_model = True

# %%
#%%
if net_type == "spinn":
    dde.config.set_default_autodiff("forward")

x_max = 2.0
y_max = 2.0
R = 0.5
E = 210e3  # Young's modulus
nu = 0.3  # Poisson's ratio

lmbd = E * nu / ((1 + nu) * (1 - 2 * nu))  # Lame's first parameter
mu = E / (2 * (1 + nu))  # Lame's second parameter

# Load
pstress = 1.0


sin = dde.backend.sin
cos = dde.backend.cos
stack = dde.backend.stack

# Load geometry mapping
nx=100
ny=100
dir_path = r"."
Xp = np.loadtxt(os.path.join(dir_path, f"plate_hole_quarter_{nx}x{ny}.txt"))

# Interpolate mapping
X_map_points = Xp[:, 0].reshape((ny, nx)).T
Y_map_points = Xp[:, 1].reshape((ny, nx)).T

@dde.utils.list_handler
def transform_coords(x):
    """
    For SPINN, if the input x is provided as a list of 1D arrays (e.g., [X_coords, Y_coords]),
    this function creates a 2D meshgrid and stacks the results into a 2D coordinate array.
    """
    x_mesh = [x_.ravel() for x_ in jnp.meshgrid(jnp.atleast_1d(x[0].squeeze()), jnp.atleast_1d(x[1].squeeze()), indexing="ij")]
    return dde.backend.stack(x_mesh, axis=-1)

def coordMap(x, X_map = X_map_points, Y_map = Y_map_points, x_max = x_max, y_max=y_max, padding=1e-6):
    x_pos = x[0] / x_max * (X_map.shape[0]-1) * (1-2*padding) + padding
    y_pos = x[1] / y_max * (Y_map.shape[1]-1) * (1-2*padding) + padding
    xm = jax.scipy.ndimage.map_coordinates(X_map,
           [x_pos, y_pos], order=1, mode='nearest')
    ym = jax.scipy.ndimage.map_coordinates(Y_map,
           [x_pos, y_pos], order=1, mode='nearest')
    return jnp.stack([xm, ym])

def F(x, phys_xy, X_map, Y_map, x_max, y_max, padding):
    return coordMap(x, X_map, Y_map, x_max, y_max, padding) - phys_xy

@jax.jit
def inv_coord_map(phys_xy, X_map = X_map_points, Y_map = Y_map_points, x_max = x_max, y_max=y_max, padding=1e-6):
    # initial guess at the center
    init_guess = jnp.array([0.5 * x_max, 0.5 * y_max])
    solver = GaussNewton(residual_fun=F,
                            tol=1e-6,
                            maxiter=25,
                            implicit_diff=True)
    sol = solver.run(
        init_params=init_guess,
        phys_xy=phys_xy,
        X_map=X_map,
        Y_map=Y_map,
        x_max=x_max,
        y_max=y_max,
        padding=padding
    ).params
    return sol


def tensMap(tens, x):
    J = jax.jacobian(coordMap)(x)
    J_inv = jnp.linalg.inv(J)
    return tens @ J_inv

def calcNormal(x):
    n = jnp.array([-1, 0])
    n_mapped = tensMap(n, x)
    return n_mapped/jnp.linalg.norm(n_mapped)
    

# Load solution
n_mesh_x = 100
n_mesh_y = 100

data = np.loadtxt(os.path.join(dir_path, f"fem_solution_{n_mesh_x}x{n_mesh_y}.dat"))
X_val = data[:, :2]
u_val = data[:, 2:4]
stress_val = data[:, 7:10]

solution_val = np.hstack((u_val, stress_val))

# Interpolate solution
x_grid = np.linspace(0, x_max, n_mesh_x)
y_grid = np.linspace(0, y_max, n_mesh_y)

interpolators = []
for i in range(solution_val.shape[1]):
    interp = RegularGridInterpolator((x_grid, y_grid), solution_val[:, i].reshape(n_mesh_y, n_mesh_x).T)
    interpolators.append(interp)

# def list_handler(func):
#     @wraps(func)
#     def wrapper(*args, **kwargs):
#         inputs = args[-1]

#         def apply_and_concat(item):
#             if isinstance(item, (list, tuple)) and all(isinstance(subitem, (list, tuple)) for subitem in item):
#                 return jnp.concat([apply_and_concat(subitem) for subitem in item], axis=0)
#             return func(*args[:-1], item, **kwargs)

#         return apply_and_concat(inputs)

#     return wrapper

# @list_handler
def solution_fn(x):
    if net_type == "spinn" and isinstance(x, list):
        x_mesh = [x_.ravel() for x_ in jnp.meshgrid(
            jnp.atleast_1d(x[0].squeeze()), 
            jnp.atleast_1d(x[1].squeeze()), 
            indexing="ij"
        )]
        x = stack(x_mesh, axis=-1)
    # x = jax.vmap(coordMap)(x)
    return np.array([interp((x[:,0], x[:,1])) for interp in interpolators]).T

geom = dde.geometry.Rectangle([0, 0], [x_max, y_max])



# geom = dde.geometry.ListPointCloud([x_train, y_train])


def HardBC(x, f):
    if net_type == "spinn" and isinstance(x, list):
        x_mesh = [x_.ravel() for x_ in jnp.meshgrid(
            jnp.atleast_1d(x[0].squeeze()), 
            jnp.atleast_1d(x[1].squeeze()), 
            indexing="ij"
        )]
        x = stack(x_mesh, axis=-1)
    x_mapped = jax.vmap(coordMap)(x)

    Ux = f[:, 0] * x_mapped[:, 0] / x_max * (y_max - x[:, 1]) / x_max * u_0
    Uy = f[:, 1] * x[:, 1] / x_max *u_0

    Sxx = f[:, 2] * (x_max - x[:, 0]) / x_max
    Syy = f[:, 3] * (y_max - x[:, 1]) / x_max + pstress
    Sxy = f[:, 4] * x_mapped[:, 0] / x_max * x[:, 1] / x_max * (x_max - x[:, 0]) / x_max

    return stack((Ux, Uy, Sxx, Syy, Sxy), axis=1)


def pde(x, f):
    # x_mesh = jnp.meshgrid(x[:,0].ravel(), x[:,0].ravel(), indexing='ij')
    x = transform_coords(x)
    # x_phys = jax.vmap(coordMap)(x)

    J_nn = jax.vmap(jax.jacfwd(f[1]))(x)
    J_comp2phys = jax.vmap(jax.jacfwd(coordMap))(x)
    J_phys2comp = jnp.linalg.inv(J_comp2phys)

    J = jnp.einsum("ijk,ikl->ijl", J_nn, J_phys2comp)

    E_xx = J[:, 0:1, 0:1]
    E_yy = J[:, 1:2, 1:2]
    E_xy = 0.5 * (J[:, 0:1, 1:2] + J[:, 1:2, 0:1])
    # E_xx = dde.grad.jacobian(f, x, i=0, j=0)[0] 
    # E_yy = dde.grad.jacobian(f, x, i=1, j=1)[0]
    # E_xy = 0.5 * (dde.grad.jacobian(f, x, i=0, j=1)[0] + dde.grad.jacobian(f, x, i=1, j=0)[0])

    S_xx = E_xx * (2 * mu + lmbd) + E_yy * lmbd
    S_yy = E_yy * (2 * mu + lmbd) + E_xx * lmbd
    S_xy = E_xy * 2 * mu

    Sxx_x = J[:, 2:3, 0:1]
    Syy_y = J[:, 3:4, 1:2]
    Sxy_x = J[:, 4:5, 0:1]
    Sxy_y = J[:, 4:5, 1:2]

    # Sxx_x = dde.grad.jacobian(f, x, i=2, j=0)[0]
    # Syy_y = dde.grad.jacobian(f, x, i=3, j=1)[0]
    # Sxy_x = dde.grad.jacobian(f, x, i=4, j=0)[0]
    # Sxy_y = dde.grad.jacobian(f, x, i=4, j=1)[0]

    momentum_x = Sxx_x + Sxy_y 
    momentum_y = Sxy_x + Syy_y 

    # if dde.backend.backend_name == "jax":
    #     f = f[0]  # f[1] is the function used by jax to compute the gradients

    stress_x = S_xx - f[0][:, 2:3]
    stress_y = S_yy - f[0][:, 3:4]
    stress_xy = S_xy - f[0][:, 4:5]

    return [momentum_x, momentum_y, stress_x, stress_y, stress_xy]

# Integral stress BC
n_integral = 100
x_integral = np.linspace(0, x_max, n_integral).reshape(-1, 1)
y_integral = np.linspace(0, y_max, n_integral).reshape(-1, 1)
integral_points = [x_integral, y_integral]

def integral_stress(inputs, outputs, X):
    if net_type == "spinn" and isinstance(inputs, list):
        x_mesh = [x_.ravel() for x_ in jnp.meshgrid(
            jnp.atleast_1d(inputs[0].squeeze()), 
            jnp.atleast_1d(inputs[1].squeeze()), 
            indexing="ij"
        )]
        x = stack(x_mesh, axis=-1)
    x_mesh = jax.vmap(coordMap)(x)[:,0].reshape((inputs[0].shape[0], inputs[0].shape[0]))

    Syy = outputs[0][:, 3:4].reshape(x_mesh.shape)
    return jnp.trapezoid(Syy, x_mesh, axis=0)

Integral_BC = dde.PointSetOperatorBC(integral_points, pstress*x_max, integral_stress)

# Free surface BC
n_free = 400
y_free = jnp.linspace(0, x_max, n_free)
X_free = jnp.stack((jnp.zeros(n_free), y_free), axis=1)
sharp_corner_tol = 0.1

mask = (jax.vmap(coordMap)(X_free)[:, 1] < R-sharp_corner_tol) & (sharp_corner_tol < jax.vmap(coordMap)(X_free)[:, 1])
X_free = X_free[mask] #keep bottom left corner: 99 points

X_list = [jnp.array([0]).reshape(-1, 1), X_free[:, 1].reshape(-1, 1)]

def free_surface_balance(inputs, outputs, X):
    if net_type == "spinn" and isinstance(inputs, list):
        x_mesh = [x_.ravel() for x_ in jnp.meshgrid(
            jnp.atleast_1d(inputs[0].squeeze()), 
            jnp.atleast_1d(inputs[1].squeeze()), 
            indexing="ij"
        )]
        inputs = stack(x_mesh, axis=-1)
    outputs = outputs[0]
    normal = jax.vmap(calcNormal)(inputs)
    normal_x, normal_y = normal[0], normal[1]
    Sxx = outputs[:, 2:3]
    Syy = outputs[:, 3:4]
    Sxy = outputs[:, 4:5]

    balance_x = Sxx * normal_x + Sxy * normal_y
    balance_y = Sxy * normal_x + Syy * normal_y
    return jnp.abs(balance_x) + jnp.abs(balance_y)

Free_BC = dde.PointSetOperatorBC(X_list, 0, free_surface_balance)

bcs = [Free_BC,Integral_BC]#Free_BC,Integral_BC]
num_boundary = 0



X_DIC_input = [np.linspace(0, x_max, n_DIC).reshape(-1, 1)] * 2

DIC_data = solution_fn(X_DIC_input)[:, :2]
DIC_data += np.random.normal(0, noise_magnitude, DIC_data.shape)

DIC_norms = np.mean(np.abs(DIC_data), axis=0) # to normalize the loss
measure_Ux = dde.PointSetOperatorBC(X_DIC_input, DIC_data[:, 0:1]/DIC_norms[0],
                                        lambda x, f, x_np: f[0][:, 0:1]/DIC_norms[0])
measure_Uy = dde.PointSetOperatorBC(X_DIC_input, DIC_data[:, 1:2]/DIC_norms[1],
                                        lambda x, f, x_np: f[0][:, 1:2]/DIC_norms[1])
bcs += [measure_Ux, measure_Uy]

def get_num_params(net, input_shape=None):
    if dde.backend.backend_name == "pytorch":
        return sum(p.numel() for p in net.parameters())
    elif dde.backend.backend_name == "paddle":
        return sum(p.numpy().size for p in net.parameters())
    elif dde.backend.backend_name == "jax":
        if input_shape is None:
            raise ValueError("input_shape must be provided for jax backend")
        import jax
        import jax.numpy as jnp

        rng = jax.random.PRNGKey(0)
        return sum(
            p.size for p in jax.tree.leaves(net.init(rng, jnp.ones(input_shape)))
        )


activation = "tanh"
initializer = "Glorot uniform"
optimizer = "adam"
h_plot = 0.02
if net_type == "spinn":
    layers = [2, 32, 32, 32, 5]
    net = dde.nn.SPINN(layers, activation, initializer, mlp)
    num_point = 200**2
    total_points = num_point**2 + num_boundary**2
    num_params = get_num_params(net, input_shape=layers[0])
    x_plot = np.linspace(0,x_max,100)
    y_plot = np.linspace(0,y_max,100)
    X_plot = np.stack((x_plot, y_plot), axis=1)

else:
    layers = [2, [40] * 5, [40] * 5, [40] * 5, [40] * 5, 5]
    net = dde.nn.PFNN(layers, activation, initializer)
    num_point = 500
    total_points = num_point + num_boundary
    num_params = get_num_params(net, input_shape=layers[0])
    X_mesh = np.meshgrid(
        np.linspace(0, x_max, int(x_max/h_plot)),
        np.linspace(0, y_max, int(y_max/h_plot)),
        indexing="ij",
    )
    X_plot = np.stack((X_mesh[0].ravel(), X_mesh[1].ravel()), axis=1)

num_test = 10000

data = dde.data.PDE(
    geom,
    pde,
    bcs,
    num_domain=num_point,
    num_boundary=num_boundary,
    solution=solution_fn,
    num_test=num_test,
    is_SPINN=net_type == "spinn",
)

if bc_type == "hard":
    net.apply_output_transform(HardBC)

model = dde.Model(data, net)
model.compile(optimizer, lr=lr, metrics=["l2 relative error"], loss_weights=loss_weights)

# n_iter = 1000
# log_every = 10
# save_model_path = "/home/dbey/SPIQ/deep_notched/test_model"
# losshistory, train_state = model.train(
#     iterations=n_iter, callbacks=callbacks, display_every=log_every
# )
# Out:
# Set the default automatic differentiation to forward mode.
# Compiling model...
# 'compile' took 0.133248 s

# %%
n_iter = 2000
log_every = 100
save_model_path = "/home/dbey/SPIQ/deep_notched/test_model"
losshistory, train_state = model.train(
    iterations=n_iter, display_every=log_every
)
# Out:
# Training model...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 4
#       2 log_every = 100
#       3 save_model_path = "/home/dbey/SPIQ/deep_notched/test_model"
# ----> 4 losshistory, train_state = model.train(
#       5     iterations=n_iter, display_every=log_every
#       6 )
#
# File ~/code/deepxde/deepxde/utils/internal.py:22, in timing.<locals>.wrapper(*args, **kwargs)
#      19 @wraps(f)
#      20 def wrapper(*args, **kwargs):
#      21     ts = timeit.default_timer()
# ---> 22     result = f(*args, **kwargs)
#      23     te = timeit.default_timer()
#      24     if config.rank == 0:
#
# File ~/code/deepxde/deepxde/model.py:647, in Model.train(self, iterations, batch_size, display_every, disregard_previous_best, callbacks, model_restore_path, model_save_path, epochs)
#     645 self.train_state.set_data_train(*self.data.train_next_batch(self.batch_size))
#     646 self.train_state.set_data_test(*self.data.test())
# --> 647 self._test()
#     648 self.callbacks.on_train_begin()
#     649 if optimizers.is_external_optimizer(self.opt_name):
#
# File ~/code/deepxde/deepxde/model.py:842, in Model._test(self)
#     831 def _test(self):
#     832     # TODO Now only print the training loss in rank 0. The correct way is to print the average training loss of all ranks.
#     833     (
#     834         self.train_state.y_pred_train,
#     835         self.train_state.loss_train,
#    (...)
#     840         self.train_state.train_aux_vars,
#     841     )
# --> 842     self.train_state.y_pred_test, self.train_state.loss_test = self._outputs_losses(
#     843         False,
#     844         self.train_state.X_test,
#     845         self.train_state.y_test,
#     846         self.train_state.test_aux_vars,
#     847     )
#     849     if isinstance(self.train_state.y_test, (list, tuple)):
#     850         self.train_state.metrics_test = [
#     851             m(self.train_state.y_test[i], self.train_state.y_pred_test[i])
#     852             for m in self.metrics
#     853             for i in range(len(self.train_state.y_test))
#     854         ]
#
# File ~/code/deepxde/deepxde/model.py:559, in Model._outputs_losses(self, training, inputs, targets, auxiliary_vars)
#     556     self.net.requires_grad_()
#     557 elif backend_name == "jax":
#     558     # TODO: auxiliary_vars
# --> 559     outs = outputs_losses(self.params, inputs, targets)
#     560 elif backend_name == "paddle":
#     561     outs = outputs_losses(inputs, targets, auxiliary_vars)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/pjit.py:338, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     335 if config.no_tracing.value:
#     336   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     337                      "`jit`, but 'no_tracing' is set")
# --> 338 outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     339     fun, jit_info, *args, **kwargs)
#     340 executable = _read_most_recent_pjit_call_executable(jaxpr)
#     341 pgle_profiler = _read_pgle_profiler(jaxpr)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/pjit.py:178, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     177 def _python_pjit_helper(fun, jit_info, *args, **kwargs):
# --> 178   p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#     180   for arg in args_flat:
#     181     dispatch.check_arg(arg)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/pjit.py:744, in _infer_params(fun, ji, args, kwargs)
#     741 entry = _infer_params_cached(
#     742     fun, ji, signature, avals, pjit_mesh, resource_env)
#     743 if entry.pjit_params is None:
# --> 744   p, args_flat = _infer_params_impl(
#     745       fun, ji, pjit_mesh, resource_env, args, kwargs, in_avals=avals)
#     746   if p.attrs_tracked:
#     747     # If there are attrs_tracked, don't use the cache.
#     748     return p, p.consts + args_flat
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/pjit.py:641, in _infer_params_impl(***failed resolving arguments***)
#     635 in_shardings_flat, in_layouts_flat = _process_in_axis_resources(
#     636     in_shardings_treedef, in_shardings_leaves,
#     637     ji.in_layouts_treedef, ji.in_layouts_leaves,
#     638     in_avals, in_tree, dbg, device_or_backend_set, have_kwargs)
#     640 attr_token = _attr_token(flat_fun, in_type)
# --> 641 jaxpr, consts, out_avals, attrs_tracked = _create_pjit_jaxpr(
#     642     flat_fun, in_type, attr_token, dbg,
#     643     HashableFunction(res_paths, closure=()),
#     644     IgnoreKey(ji.inline))
#     645 _attr_update(flat_fun, in_type, attr_token, attrs_tracked)
#     647 out_shardings_flat, out_layouts_flat = _check_and_canonicalize_out_shardings(
#     648     out_shardings_treedef, out_shardings_leaves, ji.out_layouts_treedef,
#     649     ji.out_layouts_leaves, HashableFunction(out_tree, closure=()),
#     650     tuple(out_avals), jaxpr.jaxpr.debug_info, device_or_backend_set)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/linear_util.py:352, in cache.<locals>.memoized_fun(fun, *args)
#     350   fun.populate_stores(stores)
#     351 else:
# --> 352   ans = call(fun, *args)
#     353   if explain and config.explain_cache_misses.value:
#     354     explain(fun.f, cache is new_cache, cache, key)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/pjit.py:1288, in _create_pjit_jaxpr(***failed resolving arguments***)
#    1286     attrs_tracked = []
#    1287   else:
# -> 1288     jaxpr, global_out_avals, consts, attrs_tracked = pe.trace_to_jaxpr_dynamic(
#    1289         fun, in_type, debug_info=pe_debug)
#    1290     # assert attr_data is sentinel or attr_data matches attrs_tracked
#    1291
#    1292 # TODO(dougalm,mattjj): enable debug info with attrs_tracked
#    1293 if not config.dynamic_shapes.value and not attrs_tracked:
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2278, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2276 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:
#    2277   main.jaxpr_stack = ()  # type: ignore
# -> 2278   jaxpr, out_avals, consts, attrs_tracked = trace_to_subjaxpr_dynamic(
#    2279     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2280   del main, fun
#    2281 return jaxpr, out_avals, consts, attrs_tracked
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2301, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2299 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2300 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2301 ans = fun.call_wrapped(*in_tracers_)
#    2302 out_tracers = map(trace.full_raise, ans)
#    2303 jaxpr, consts, attrs_tracked = frame.to_jaxpr(trace, out_tracers)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
# File ~/code/deepxde/deepxde/model.py:422, in Model._compile_jax.<locals>.outputs_losses_test(params, inputs, targets)
#     420 @jax.jit
#     421 def outputs_losses_test(params, inputs, targets):
# --> 422     return outputs_losses(params, False, inputs, targets, self.data.losses_test)
#
# File ~/code/deepxde/deepxde/model.py:403, in Model._compile_jax.<locals>.outputs_losses(params, training, inputs, targets, losses_fn)
#     400 def outputs_fn(inputs):
#     401     return outputs(nn_params, training, inputs)
# --> 403 outputs_ = outputs(nn_params, training, inputs)
#     404 # Data losses
#     405 # We use aux so that self.data.losses is a pure function.
#     406 aux = [outputs_fn, ext_params] if ext_params else [outputs_fn]
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/pjit.py:338, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     335 if config.no_tracing.value:
#     336   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     337                      "`jit`, but 'no_tracing' is set")
# --> 338 outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     339     fun, jit_info, *args, **kwargs)
#     340 executable = _read_most_recent_pjit_call_executable(jaxpr)
#     341 pgle_profiler = _read_pgle_profiler(jaxpr)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/pjit.py:178, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     177 def _python_pjit_helper(fun, jit_info, *args, **kwargs):
# --> 178   p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#     180   for arg in args_flat:
#     181     dispatch.check_arg(arg)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/pjit.py:744, in _infer_params(fun, ji, args, kwargs)
#     741 entry = _infer_params_cached(
#     742     fun, ji, signature, avals, pjit_mesh, resource_env)
#     743 if entry.pjit_params is None:
# --> 744   p, args_flat = _infer_params_impl(
#     745       fun, ji, pjit_mesh, resource_env, args, kwargs, in_avals=avals)
#     746   if p.attrs_tracked:
#     747     # If there are attrs_tracked, don't use the cache.
#     748     return p, p.consts + args_flat
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/pjit.py:641, in _infer_params_impl(***failed resolving arguments***)
#     635 in_shardings_flat, in_layouts_flat = _process_in_axis_resources(
#     636     in_shardings_treedef, in_shardings_leaves,
#     637     ji.in_layouts_treedef, ji.in_layouts_leaves,
#     638     in_avals, in_tree, dbg, device_or_backend_set, have_kwargs)
#     640 attr_token = _attr_token(flat_fun, in_type)
# --> 641 jaxpr, consts, out_avals, attrs_tracked = _create_pjit_jaxpr(
#     642     flat_fun, in_type, attr_token, dbg,
#     643     HashableFunction(res_paths, closure=()),
#     644     IgnoreKey(ji.inline))
#     645 _attr_update(flat_fun, in_type, attr_token, attrs_tracked)
#     647 out_shardings_flat, out_layouts_flat = _check_and_canonicalize_out_shardings(
#     648     out_shardings_treedef, out_shardings_leaves, ji.out_layouts_treedef,
#     649     ji.out_layouts_leaves, HashableFunction(out_tree, closure=()),
#     650     tuple(out_avals), jaxpr.jaxpr.debug_info, device_or_backend_set)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/linear_util.py:352, in cache.<locals>.memoized_fun(fun, *args)
#     350   fun.populate_stores(stores)
#     351 else:
# --> 352   ans = call(fun, *args)
#     353   if explain and config.explain_cache_misses.value:
#     354     explain(fun.f, cache is new_cache, cache, key)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/pjit.py:1288, in _create_pjit_jaxpr(***failed resolving arguments***)
#    1286     attrs_tracked = []
#    1287   else:
# -> 1288     jaxpr, global_out_avals, consts, attrs_tracked = pe.trace_to_jaxpr_dynamic(
#    1289         fun, in_type, debug_info=pe_debug)
#    1290     # assert attr_data is sentinel or attr_data matches attrs_tracked
#    1291
#    1292 # TODO(dougalm,mattjj): enable debug info with attrs_tracked
#    1293 if not config.dynamic_shapes.value and not attrs_tracked:
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2278, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2276 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:
#    2277   main.jaxpr_stack = ()  # type: ignore
# -> 2278   jaxpr, out_avals, consts, attrs_tracked = trace_to_subjaxpr_dynamic(
#    2279     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2280   del main, fun
#    2281 return jaxpr, out_avals, consts, attrs_tracked
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2301, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2299 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2300 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2301 ans = fun.call_wrapped(*in_tracers_)
#    2302 out_tracers = map(trace.full_raise, ans)
#    2303 jaxpr, consts, attrs_tracked = frame.to_jaxpr(trace, out_tracers)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
# File ~/code/deepxde/deepxde/utils/internal.py:257, in list_handler.<locals>.wrapper(*args, **kwargs)
#     254         return bkd.concat([apply_and_concat(subitem) for subitem in item], axis=0)
#     255     return func(*args[:-1], item, **kwargs)
# --> 257 return apply_and_concat(inputs)
#
# File ~/code/deepxde/deepxde/utils/internal.py:254, in list_handler.<locals>.wrapper.<locals>.apply_and_concat(item)
#     252 def apply_and_concat(item):
#     253     if isinstance(item, (list, tuple)) and all(isinstance(subitem, (list, tuple)) for subitem in item):
# --> 254         return bkd.concat([apply_and_concat(subitem) for subitem in item], axis=0)
#     255     return func(*args[:-1], item, **kwargs)
#
# File ~/code/deepxde/deepxde/utils/internal.py:254, in <listcomp>(.0)
#     252 def apply_and_concat(item):
#     253     if isinstance(item, (list, tuple)) and all(isinstance(subitem, (list, tuple)) for subitem in item):
# --> 254         return bkd.concat([apply_and_concat(subitem) for subitem in item], axis=0)
#     255     return func(*args[:-1], item, **kwargs)
#
# File ~/code/deepxde/deepxde/utils/internal.py:255, in list_handler.<locals>.wrapper.<locals>.apply_and_concat(item)
#     253 if isinstance(item, (list, tuple)) and all(isinstance(subitem, (list, tuple)) for subitem in item):
#     254     return bkd.concat([apply_and_concat(subitem) for subitem in item], axis=0)
# --> 255 return func(*args[:-1], item, **kwargs)
#
# File ~/code/deepxde/deepxde/model.py:394, in Model._compile_jax.<locals>.outputs(params, training, inputs)
#     391 @jax.jit
#     392 @utils.list_handler
#     393 def outputs(params, training, inputs):
# --> 394     return self.net.apply(params, inputs, training=training)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/flax/linen/module.py:2235, in Module.apply(self, variables, rngs, method, mutable, capture_intermediates, *args, **kwargs)
#    2233   method = self.__call__
#    2234 method = _get_unbound_fn(method)
# -> 2235 return apply(
#    2236   method,
#    2237   self,
#    2238   mutable=mutable,
#    2239   capture_intermediates=capture_intermediates,
#    2240 )(variables, *args, **kwargs, rngs=rngs)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/flax/core/scope.py:1079, in apply.<locals>.wrapper(variables, rngs, *args, **kwargs)
#    1074   raise errors.ApplyScopeInvalidVariablesStructureError(variables)
#    1076 with bind(
#    1077   variables, rngs=rngs, mutable=mutable, flags=flags
#    1078 ).temporary() as root:
# -> 1079   y = fn(root, *args, **kwargs)
#    1080 if mutable is not False:
#    1081   return y, root.mutable_variables()
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/flax/linen/module.py:3017, in apply.<locals>.scope_fn(scope, *args, **kwargs)
#    3015 _context.capture_stack.append(capture_intermediates)
#    3016 try:
# -> 3017   return fn(module.clone(parent=scope, _deep_clone=True), *args, **kwargs)
#    3018 finally:
#    3019   _context.capture_stack.pop()
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/flax/linen/module.py:699, in wrap_method_once.<locals>.wrapped_module_method(*args, **kwargs)
#     697 if args and isinstance(args[0], Module):
#     698   self, args = args[0], args[1:]
# --> 699   return self._call_wrapped_method(fun, args, kwargs)
#     700 else:
#     701   return fun(*args, **kwargs)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/flax/linen/module.py:1216, in Module._call_wrapped_method(self, fun, args, kwargs)
#    1214 if _use_named_call:
#    1215   with jax.named_scope(_derive_profiling_name(self, fun)):
# -> 1216     y = run_fun(self, *args, **kwargs)
#    1217 else:
#    1218   y = run_fun(self, *args, **kwargs)
#
# File ~/code/deepxde/deepxde/nn/jax/snn.py:63, in SPINN.__call__(self, inputs, training)
#      60     outputs = self.SPINNnd(list_inputs)
#      62 if self._output_transform is not None:
# ---> 63     outputs = self._output_transform(inputs, outputs)
#      65 return outputs
#
# File ~/code/deepxde/deepxde/nn/jax/nn.py:37, in NN.apply_output_transform.<locals>.transform_handling_flat(inputs, outputs)
#      35 # TODO: Support tuple or list inputs.
#      36 if isinstance(inputs, (list, tuple)):
# ---> 37     return transform(inputs, outputs)
#      38 if inputs.ndim == 1:
#      39     return transform(inputs.reshape(1, -1), outputs.reshape(1, -1)).reshape(-1)
#
# Cell In[10], line 154, in HardBC(x, f)
#     151 Syy = f[:, 3] * (y_max - x[:, 1]) / x_max + pstress
#     152 Sxy = f[:, 4] * x_mapped[:, 0] / x_max * x[:, 1] / x_max * (x_max - x[:, 0]) / x_max
# --> 154 return stack((Ux, Uy, Sxx, Syy, Sxy), axis=1)
#
# File ~/code/deepxde/deepxde/backend/jax/tensor.py:78, in stack(values, axis)
#      77 def stack(values, axis):
# ---> 78     return jnp.stack(values, axis=axis)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:4476, in stack(arrays, axis, out, dtype)
#    4474     raise ValueError("All input arrays must have the same shape.")
#    4475   new_arrays.append(expand_dims(a, axis))
# -> 4476 return concatenate(new_arrays, axis=axis, dtype=dtype)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:4640, in concatenate(arrays, axis, dtype)
#    4638 k = 16
#    4639 while len(arrays_out) > 1:
# -> 4640   arrays_out = [lax.concatenate(arrays_out[i:i+k], axis)
#    4641                 for i in range(0, len(arrays_out), k)]
#    4642 return arrays_out[0]
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:4640, in <listcomp>(.0)
#    4638 k = 16
#    4639 while len(arrays_out) > 1:
# -> 4640   arrays_out = [lax.concatenate(arrays_out[i:i+k], axis)
#    4641                 for i in range(0, len(arrays_out), k)]
#    4642 return arrays_out[0]
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/lax/lax.py:652, in concatenate(operands, dimension)
#     650   if isinstance(op, Array):
#     651     return op
# --> 652 return concatenate_p.bind(*operands, dimension=dimension)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/core.py:438, in Primitive.bind(self, *args, **params)
#     435 def bind(self, *args, **params):
#     436   assert (not config.enable_checks.value or
#     437           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 438   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/core.py:442, in Primitive.bind_with_trace(self, trace, args, params)
#     440 def bind_with_trace(self, trace, args, params):
#     441   with pop_level(trace.level):
# --> 442     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     443   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:1969, in DynamicJaxprTrace.process_primitive(self, primitive, tracers, params)
#    1967 if primitive in custom_staging_rules:
#    1968   return custom_staging_rules[primitive](self, *tracers, **params)
# -> 1969 return self.default_process_primitive(primitive, tracers, params)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:1973, in DynamicJaxprTrace.default_process_primitive(self, primitive, tracers, params)
#    1971 def default_process_primitive(self, primitive, tracers, params):
#    1972   avals = [t.aval for t in tracers]
# -> 1973   out_avals, effects = primitive.abstract_eval(*avals, **params)
#    1974   if isinstance(out_avals, (tuple, list)) != primitive.multiple_results:
#    1975     raise ValueError(f"{primitive}.abstract_eval() method should return "
#    1976                      f"a tuple or a list iff {primitive}.multiple_results.")
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/core.py:475, in _effect_free_abstract_eval.<locals>.abstract_eval_(*args, **kwargs)
#     474 def abstract_eval_(*args, **kwargs):
# --> 475   return abstract_eval(*args, **kwargs), no_effects
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/lax/utils.py:60, in standard_abstract_eval(prim, shape_rule, dtype_rule, weak_type_rule, sharding_rule, *avals, **kwargs)
#      57   return core.ConcreteArray(out.dtype, out, weak_type=weak_type)
#      58 elif least_specialized is core.ShapedArray:
#      59   return core.ShapedArray(
# ---> 60       shape_rule(*avals, **kwargs), dtype_rule(*avals, **kwargs),
#      61       weak_type=weak_type,
#      62       sharding=(sharding_rule(*avals, **kwargs)
#      63                 if config.sharding_in_types.value else None))
#      64 elif least_specialized is core.DShapedArray:
#      65   shape = shape_rule(*avals, **kwargs)
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/lax/lax.py:4286, in _concatenate_dtype_rule(*operands, **kwargs)
#    4285 def _concatenate_dtype_rule(*operands, **kwargs):
# -> 4286   check_same_dtypes('concatenate', *operands)
#    4287   return operands[0].dtype
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/lax/lax.py:5973, in check_same_dtypes(name, *avals)
#    5970   return
#    5972 dtype = dtypes.canonicalize_dtype(avals[0].dtype)
# -> 5973 if any(dtypes.canonicalize_dtype(aval.dtype) != dtype for aval in avals[1:]):
#    5974   msg = "lax.{} requires arguments to have the same dtypes, got {}."
#    5975   if name in _JNP_FUNCTION_EQUIVALENTS:
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/lax/lax.py:5973, in <genexpr>(.0)
#    5970   return
#    5972 dtype = dtypes.canonicalize_dtype(avals[0].dtype)
# -> 5973 if any(dtypes.canonicalize_dtype(aval.dtype) != dtype for aval in avals[1:]):
#    5974   msg = "lax.{} requires arguments to have the same dtypes, got {}."
#    5975   if name in _JNP_FUNCTION_EQUIVALENTS:
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/jax/_src/dtypes.py:254, in canonicalize_dtype(dtype, allow_extended_dtype)
#     251 @overload
#     252 def canonicalize_dtype(dtype: Any, allow_extended_dtype: bool = False) -> DType | ExtendedDType: ...
# --> 254 @export
#     255 def canonicalize_dtype(dtype: Any, allow_extended_dtype: bool = False) -> DType | ExtendedDType:
#     256   """Convert from a dtype to a canonical dtype based on config.x64_enabled."""
#     257   return _canonicalize_dtype(config.enable_x64.value, allow_extended_dtype, dtype)  # pytype: disable=bad-return-type
#
# File _pydevd_bundle\\pydevd_cython.pyx:1697, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\\pydevd_cython.pyx:2017, in _pydevd_bundle.pydevd_cython.ThreadTracer.__call__()
#
# File ~/miniconda3/envs/jax/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_is_thread_alive.py:16, in is_thread_alive(t)
#      11         return not t._handle.is_done()
#      14 elif hasattr(_temp, "_is_stopped"):  # Python 3.12 and earlier has this
# ---> 16     def is_thread_alive(t):
#      17         return not t._is_stopped
#      19 elif hasattr(_temp, "_Thread__stopped"):  # Python 2.x has this
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

R=0.5
L=2.0
ngrid=100

x_bcs = np.linspace(0,L,ngrid).reshape(-1,1)
y_bcs = np.linspace(0,L,ngrid).reshape(-1,1)
# X_input_bcs = np.stack((x_bcs, y_bcs), axis=1)
X_input_bcs = [[x_bcs, y_bcs]]
F_bcs = model.predict(X_input_bcs)

x_center = np.linspace(0,L,2*ngrid)[1:-1:2].reshape(-1,1)
y_center = np.linspace(0,L,2*ngrid)[1:-1:2].reshape(-1,1)
# X_input = np.stack((x_center, y_center), axis=1)
Xgrid_sol, Ygrid_sol = np.meshgrid(x_center, y_center, indexing="ij")
grad_vmap = jax.vmap(jax.jacfwd(coordMap))(np.stack((Xgrid_sol.ravel(), Ygrid_sol.ravel()), axis=1))

fig, ax = plt.subplots(2, 2, figsize=(5, 5))
for i in range(4):
    ax[i//2, i%2].hist(grad_vmap[:,i//2:i//2+1,i%2], bins=100, label=f"max: {np.max(grad_vmap[:,i//2:i//2+1,i%2]):.3f}\nmin: {np.min(grad_vmap[:,i//2:i//2+1,i%2]):.3f}\nmean: {np.mean(grad_vmap[:,i//2:i//2+1,i%2]):.3f}")
    ax[i//2, i%2].legend()
plt.suptitle("Gradient of the mapping")
plt.show()

# plt.hist(grad_vmap[:,0:1,0], bins=100)

# %%
import matplotlib.colors as colors
import os
from scipy.interpolate import RegularGridInterpolator
import matplotlib.ticker as ticker
import matplotlib.transforms as mtransforms
import matplotlib.pyplot as plt

R=0.5
L=2.0
ngrid=100

x_bcs = np.linspace(0,L,ngrid).reshape(-1,1)
y_bcs = np.linspace(0,L,ngrid).reshape(-1,1)
# X_input_bcs = np.stack((x_bcs, y_bcs), axis=1)
X_input_bcs = [[x_bcs, y_bcs]]
F_bcs = model.predict(X_input_bcs)

x_center = np.linspace(0,L,2*ngrid)[1:-1:2].reshape(-1,1)
y_center = np.linspace(0,L,2*ngrid)[1:-1:2].reshape(-1,1)
# X_input = np.stack((x_center, y_center), axis=1)
Xgrid_sol, Ygrid_sol = np.meshgrid(x_center, y_center, indexing="ij")
Xmesh_sol = jax.vmap(coordMap)(np.stack((Xgrid_sol.ravel(), Ygrid_sol.ravel()), axis=1))
Xmesh_sol, Ymesh_sol = Xmesh_sol[:,0].reshape(Xgrid_sol.shape), Xmesh_sol[:,1].reshape(Ygrid_sol.shape)

X_input = [[x_center, y_center]]
x_edge = np.linspace(0,L,ngrid)
y_edge = np.linspace(0,L,ngrid)

Xgrid, Ygrid = np.meshgrid(x_edge, y_edge, indexing="ij")
Xmesh = jax.vmap(coordMap)(np.stack((Xgrid.ravel(), Ygrid.ravel()), axis=1))
Xmesh, Ymesh = Xmesh[:,0].reshape(Xgrid.shape), Xmesh[:,1].reshape(Ygrid.shape)

F = model.predict(X_input)
Ux = F[:, 0:1].reshape(len(x_center), len(y_center))
Uy = F[:, 1].reshape(len(x_center), len(y_center))
Sxx = F[:, 2].reshape(len(x_center), len(y_center))
Syy = F[:, 3].reshape(len(x_center), len(y_center))
Sxy = F[:, 4].reshape(len(x_center), len(y_center))


cmap = plt.get_cmap('viridis')
num_colors = 20
color_values = [cmap(i) for i in np.linspace(0, 1, num_colors)]
cmap = colors.ListedColormap(color_values)

def pcolor_plot(AX, X, Y, C, title,colormap=cmap,norm=None):

    # X, Y = compute_edges_from_nodes(X, Y)
    im = AX.pcolormesh(X, Y, C, cmap=colormap,shading='auto',norm=norm, edgecolors='none', linewidth=0.01)

    AX.axis("equal")
    AX.axis("off")
    AX.set_title(title, fontsize=14)
    return im

# fig, axs = plt.subplots(1, 2, figsize=(16, 6))
# im = pcolor_plot(axs[0], Xmesh, Ymesh, Ux, "Ux")
# fig.colorbar(im, ax=axs[0], format=ticker.FuncFormatter(lambda x, _: f"{x:.1e}"))
# im = pcolor_plot(axs[1], Xmesh, Ymesh, Uy, "Uy")
# fig.colorbar(im, ax=axs[1], format=ticker.FuncFormatter(lambda x, _: f"{x:.1e}"))

# fig, axs = plt.subplots(1, 3, figsize=(24, 6))
# im = pcolor_plot(axs[0], Xmesh, Ymesh, Sxx, "Sxx")
# fig.colorbar(im, ax=axs[0], format=ticker.FuncFormatter(lambda x, _: f"{x:.1e}"))
# im = pcolor_plot(axs[1], Xmesh, Ymesh, Syy, "Syy")
# fig.colorbar(im, ax=axs[1], format=ticker.FuncFormatter(lambda x, _: f"{x:.1e}"))
# im = pcolor_plot(axs[2], Xmesh, Ymesh, Sxy, "Sxy")
# fig.colorbar(im, ax=axs[2], format=ticker.FuncFormatter(lambda x, _: f"{x:.1e}"))

# %%
fields_bc_true = [solution_fn(np.hstack((Xgrid.reshape(-1, 1), Ygrid.reshape(-1, 1))))[:, i].reshape(Xgrid.shape) for i in range(5)]
fields_true = [solution_fn(np.hstack((Xgrid_sol.reshape(-1, 1), Ygrid_sol.reshape(-1, 1))))[:, i].reshape(Xgrid_sol.shape) for i in range(5)]

titles = ["Ux", "Uy", "Sxx", "Syy", "Sxy"]
fields = [Ux, Uy, Sxx, Syy, Sxy]
fig, axs = plt.subplots(3, 2, figsize=(8, 10))
for i, ax in enumerate(axs.T):
    im = pcolor_plot(ax[0], Xmesh, Ymesh, fields_true[i], titles[i]+"_true")
    fig.colorbar(im, ax=ax[0], format=ticker.FuncFormatter(lambda x, _: f"{x:.1e}"))
    norm = colors.Normalize(vmin=fields_true[i].min(), vmax=fields_true[i].max())
    im = pcolor_plot(ax[1], Xmesh, Ymesh, fields[i], titles[i]+"_pred")#,norm=norm)
    fig.colorbar(im, ax=ax[1], format=ticker.FuncFormatter(lambda x, _: f"{x:.1e}"))
    im = pcolor_plot(ax[2], Xmesh, Ymesh, fields[i] - fields_true[i], titles[i]+"_diff",colormap='coolwarm')
    fig.colorbar(im, ax=ax[2], format=ticker.FuncFormatter(lambda x, _: f"{x:.1e}"))


fig, axs = plt.subplots(3, 3, figsize=(12, 10))
for i, ax in enumerate(axs.T):
    im = pcolor_plot(ax[0], Xmesh, Ymesh, fields_true[i+2], titles[i+2]+"_true")
    fig.colorbar(im, ax=ax[0], format=ticker.FuncFormatter(lambda x, _: f"{x:.1e}"))
    norm = colors.Normalize(vmin=fields_true[i+2].min(), vmax=fields_true[i+2].max())
    im = pcolor_plot(ax[1], Xmesh, Ymesh, fields[i+2], titles[i+2]+"_pred")#,norm=norm)
    fig.colorbar(im, ax=ax[1], format=ticker.FuncFormatter(lambda x, _: f"{x:.1e}"))
    im = pcolor_plot(ax[2], Xmesh, Ymesh, fields[i+2] - fields_true[i+2], titles[i+2]+"_diff",colormap='coolwarm')
    fig.colorbar(im, ax=ax[2], format=ticker.FuncFormatter(lambda x, _: f"{x:.1e}"))

# %%
def plot_boundary(F, F_bc, F_true, X, Y, title, axs):
    x_top = X[:,-1]
    x_bottom = X[:,0]
    y_left = Y[0,:]
    y_right = Y[-1,:]

    F_top = F_bc[-1,:]
    F_bottom = F_bc[0,:]
    F_left = F_bc[:,0]
    F_right = F_bc[:,-1]

    x_bcs = [x_top, x_bottom, F_left, F_right] 
    y_bcs = [F_top, F_bottom, y_left, y_right]

    F_top_true = F_true[-1,:]
    F_bottom_true = F_true[0,:]
    F_left_true = F_true[:,0]
    F_right_true = F_true[:,-1]

    x_bcs_true = [x_top, x_bottom, F_left_true, F_right_true]
    y_bcs_true = [F_top_true, F_bottom_true, y_left, y_right]

    index_bcs = [[0,1],[2,1],[1,0],[1,2]]

    axs[0][0].axis("off")
    axs[0][2].axis("off")
    axs[2][0].axis("off")
    axs[2][2].axis("off")

    for i, (x_bc, y_bc, x_bc_true, y_bc_true, ind) in enumerate(zip(x_bcs, y_bcs, x_bcs_true, y_bcs_true, index_bcs)):
        # axs[ind[0]][ind[1]].yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f"{x:.1e}"))
        if i<2:
            axs[ind[0]][ind[1]].plot(x_bc, y_bc, label=f"max : {np.max(y_bc):.2e}\nmin : {np.min(y_bc):.2e}")
            axs[ind[0]][ind[1]].plot(x_bc_true, y_bc_true, color='red', linestyle='--')
            axs[ind[0]][ind[1]].xaxis.set_visible(False)
            axs[ind[0]][ind[1]].set_xlim([0, 2.0])
            # axs[ind[0]][ind[1]].set_ylim([min(y_bc), max(y_bc)])
            #log scale
            # axs[ind[0]][ind[1]].set_yscale('log')

        else:
            axs[ind[0]][ind[1]].plot(x_bc, y_bc, label=f"max : {np.max(x_bc):.2e}\nmin : {np.min(x_bc):.2e}")
            axs[ind[0]][ind[1]].plot(x_bc_true, y_bc_true, color='red', linestyle='--')

            axs[ind[0]][ind[1]].yaxis.set_visible(False)
            axs[ind[0]][ind[1]].set_ylim([0, 2.0])
            # axs[ind[0]][ind[1]].set_xlim([min(x_bc), max(x_bc)])
            #log scale
            # axs[ind[0]][ind[1]].set_xscale('log')
        axs[ind[0]][ind[1]].legend()
            
    im = pcolor_plot(axs[1][1], X, Y, F, None)
    axs[1][1].set_zorder(-1)
    pos = axs[1][2].get_position()
    cax = fig.add_axes([pos.width + pos.x0 +0.05, pos.y0, 0.02, pos.height])
    fig.colorbar(im, cax=cax, format=ticker.FuncFormatter(lambda x, _: f"{x:.1e}"))
    plt.tight_layout()
    plt.suptitle(title, fontsize=18)


fields = [Ux, Uy, Sxx, Syy, Sxy]
fields_bc = [F_bcs[:,i].reshape(len(x_bcs), len(y_bcs)).T for i in range(5)]
# fields_bc_true = [solution_fn(np.hstack((Xmesh.reshape(-1, 1), Ymesh.reshape(-1, 1))))[:, i].reshape(Xmesh.shape) for i in range(5)]
titles = ["Ux", "Uy", "Sxx", "Syy", "Sxy"]

for i,title in enumerate(titles):
    field = fields[i]
    field_bc = fields_bc[i]
    field_true = fields_bc_true[i].T
    fig, axs = plt.subplots(3, 3, figsize=(10, 10), height_ratios=[0.1, 0.9, 0.1], width_ratios=[0.1, 0.9, 0.1], gridspec_kw={"hspace": 0.1, "wspace": 0.1})
    plot_boundary(field, field_bc, field_true, Xmesh, Ymesh, title, axs)

# fig, axs = plt.subplots(3, 3, figsize=(10, 10), height_ratios=[0.1, 0.9, 0.1], width_ratios=[0.1, 0.9, 0.1], gridspec_kw={"hspace": 0.1, "wspace": 0.1})
# plot_boundary(Ux, Xmesh, Ymesh, "Ux", axs)
# Out:
# /tmp/ipykernel_3437726/2469572693.py:57: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
x_left = np.zeros(ngrid)
y_left = np.linspace(0, x_max, ngrid)
X_left = np.stack((x_left, y_left), axis=1)

n_free = 400
y_free = jnp.linspace(0, x_max, n_free)
X_free = jnp.stack((jnp.zeros(n_free), y_free), axis=1)
sharp_corner_tol = 0.1

mask = (jax.vmap(coordMap)(X_free)[:, 1] < R-sharp_corner_tol) & (sharp_corner_tol < jax.vmap(coordMap)(X_free)[:, 1])
X_free = X_free[mask] #keep bottom left corner: 99 points

X_list = [jnp.array([0]).reshape(-1, 1), X_free[:, 1].reshape(-1, 1)]

X_left_mapped = jax.vmap(coordMap)(X_left)

Tx = [-X_left_mapped[i,0]/R if X_left_mapped[i,1] <= R+1e-6 else -1 for i in range(ngrid)]
Ty = [-X_left_mapped[i,1]/R if X_left_mapped[i,1] <= R+1e-6 else 0 for i in range(ngrid)] 

normal_mapped = jax.vmap(calcNormal)(X_left)
Tx_j, Ty_j = normal_mapped[:, 0], normal_mapped[:, 1]
# fig, ax = plt.subplots(figsize=(10, 10))
# plt.quiver(X_left_mapped[:,0], X_left_mapped[:,1], Tx, Ty, scale=7)
# plt.quiver(X_left_mapped[:,0], X_left_mapped[:,1], Tx_j, Ty_j, scale=7, color='r')


# plt.scatter(X_left_mapped[:,0], X_left_mapped[:,1], c=Tx, cmap='viridis', s=1)
# plt.gca().set_aspect('equal', adjustable='box')
# ax.set_xlim([-0.2, 0.55])

Tx, Ty = jnp.array(Tx), jnp.array(Ty)
Sxx_left = fields_bc[2][:,0]
Syy_left = fields_bc[3][:,0]
Sxy_left = fields_bc[4][:,0]
# Sbc_left = fields_bc[5][:,0]

balance_x = Sxx_left*Tx + Sxy_left*Ty 
balance_y = Sxy_left*Tx + Syy_left*Ty

fig, axs = plt.subplots(1, 3, figsize=(15, 4))
axs[0].plot(X_left_mapped[:,1],np.array(Tx)**2 + np.array(Ty)**2, label='|T|')
axs[0].plot(X_left_mapped[:,1],Tx, label='Tx')
axs[0].plot(X_left_mapped[:,1],Ty, label='Ty')
axs[0].axvline(0.5, color='black', linestyle='--')
axs[0].legend()

axs[1].plot(X_left_mapped[:,1],balance_x, label='balance_x')
axs[1].plot(X_left_mapped[:,1],balance_y, label='balance_y')
axs[1].axvline(0.5, color='black', linestyle='--')
axs[1].legend()
axs[1].set_ylim([-0.2, 0.2])
# axs[1].set_ylim([-0.05, 0.05])

axs[2].plot(X_left_mapped[:,1],Sxx_left, label='Sxx')
axs[2].plot(X_left_mapped[:,1],Syy_left, label='Syy')
axs[2].plot(X_left_mapped[:,1],Sxy_left, label='Sxy')
axs[2].axvline(0.5, color='black', linestyle='--')
# axs[2].set_ylim([-0.3, 0.3])

# axs[2].plot(X_left_mapped[:,1],Sbc_left, label='Sbc')
axs[2].legend()


inputs = [X_list]
outputs = model.predict(inputs)
print("Balance loss:", np.mean(np.square(free_surface_balance(inputs[0], [outputs], X_left_mapped))))
print("Balance loss check:", np.mean(np.square(np.linalg.norm(balance_x[y_left<0.5]) + np.linalg.norm(balance_y[y_left<0.5]))))


def solution_fn_flat(x):
    return np.array([interp((x[:,0], x[:,1])) for interp in interpolators]).T

x_left = np.zeros(ngrid)
y_left = np.linspace(0, x_max, ngrid)
X_left = np.stack((x_left, y_left), axis=1)
X_left_mapped = jax.vmap(coordMap)(X_left)

F_left_exact = solution_fn_flat(np.stack((x_left, y_left), axis=1))

balance_x = F_left_exact[:,2]*Tx + F_left_exact[:,4]*Ty
balance_y = F_left_exact[:,4]*Tx + F_left_exact[:,3]*Ty

fig, axs = plt.subplots(1, 3, figsize=(15, 4))
axs[2].plot(X_left_mapped[:,1],F_left_exact[:,2], label='Sxx')
axs[2].plot(X_left_mapped[:,1],F_left_exact[:,3], label='Syy')
axs[2].plot(X_left_mapped[:,1],F_left_exact[:,4], label='Sxy')
axs[2].axvline(0.5, color='black', linestyle='--')
# axs[2].set_ylim([-1, 1])
axs[2].legend()

axs[1].plot(X_left_mapped[:,1],balance_x, label='balance_x')
axs[1].plot(X_left_mapped[:,1],balance_y, label='balance_y')
axs[1].axvline(0.5, color='black', linestyle='--')
# axs[1].set_ylim([-0.2, 0.2])
axs[1].legend()



print("Balance loss FEM:", np.mean(np.square(np.linalg.norm(balance_x[y_left<0.5]) + np.linalg.norm(balance_y[y_left<0.5]))))
# Out:
# Balance loss: 0.81678563
# Balance loss check: 6.048302
# Balance loss FEM: 0.47085166

# %%
import numpy as np 
ngrid = 100
x_max = 2.0
def solution_fn_flat(x):
    return np.array([interp((x[:,0], x[:,1])) for interp in interpolators]).T

x_left = np.zeros(ngrid)
y_left = np.linspace(0, x_max, ngrid)
X_left = np.stack((x_left, y_left), axis=1)
X_left_mapped = jax.vmap(coordMap)(X_left)

F_left_exact = solution_fn_flat(np.stack((x_left, y_left), axis=1))

balance_x = F_left_exact[:,2]*Tx + F_left_exact[:,4]*Ty
balance_y = F_left_exact[:,4]*Tx + F_left_exact[:,3]*Ty

fig, axs = plt.subplots(1, 2, figsize=(10, 4))
axs[1].plot(X_left_mapped[:,1],F_left_exact[:,2], label='Sxx')
axs[1].plot(X_left_mapped[:,1],F_left_exact[:,3], label='Syy')
axs[1].plot(X_left_mapped[:,1],F_left_exact[:,4], label='Sxy')
axs[1].axvline(0.5, color='black', linestyle='--')
axs[1].legend()

axs[0].plot(X_left_mapped[:,1],balance_x, label='balance_x')
axs[0].plot(X_left_mapped[:,1],balance_y, label='balance_y')
axs[0].axvline(0.5, color='black', linestyle='--')
axs[0].legend()
